# %% [markdown]
# ## Exercise 1
# 1. Создайте график $x^2⋅sin(1/x^2)+x$ на интервале $[−1,1]$, используя 250 точек. Не забудьте пометить оси!
# 2. Создайте semilogy график (с логарифмической шкалой для оси y и линейной шкалой для оси x) относительной разницы  функций $1/(1+x^2)$ и $1/x^2$ на интервале $[5,25]$. (Относительная разница чисел $a$ и $b$ определяется как $|1−a/b|$)
# 3. В Scipy также есть много менее распространенных специальных функций. Взгляните на обширный список <a href=https://docs.scipy.org/doc/scipy/reference/special.html> здесь</a>! Выберите несколько интересных спец функций, которые вы знаете (или, может быть, не знаете), подставьте несколько чисел и начертите их.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
xx = np.linspace(-1, 1, 250)
yy = xx*xx*np.sin(1/(xx*xx)) + xx
plt.plot(xx, yy)
plt.xlabel('x')
plt.ylabel('y')
plt.title(('y = $x^2⋅sin(1/x^2)+x$'))
# Out:
# Text(0.5, 1.0, 'y = $x^2⋅sin(1/x^2)+x$')

# %%
xx = np.arange(5, 25, 0.5)
yy1 = 1/(1+xx*xx)
yy2 = 1/(xx*xx)
yy = abs(1-yy1/yy2)
plt.plot(xx, yy)
plt.xlabel('x')
plt.ylabel('y')
plt.yscale('log')
plt.title('semilogy')
# Out:
# Text(0.5, 1.0, 'semilogy')

# %%
import scipy
xx = np.linspace(-10, 10, 250)
yy = scipy.special.airy(xx)[0]
yy2 = scipy.special.airy(xx)[1]
yy3 = scipy.special.ellipk(xx)
plt.figure(figsize=(12, 7))
plt.title('Scipy graphs')
plt.xlabel(u'x', family='verdana')
plt.ylabel(u'y', family='verdana')
plt.plot(xx, yy, label = 'Функция Эйри А', color = 'orange')
plt.plot(xx, yy2, label = 'Функция Эйри В', color = 'blue')
plt.plot(xx, yy3, label = 'Эллиптический интеграл первого рода', color = 'green')
plt.legend()

# %% [markdown]
# ## Exercise 2
# 1. Построить график функции $sin(x)/x$ на отрезке $[-6\pi;6\pi]$ и добавить тики по оси $x$ с шагом $\pi/2$ от $-6\pi$ до $6\pi$, причём обозначения тиков должны содержать греческую букву $\pi$. Добавить сетку на график.

# %%
xx = np.linspace(-6*np.pi,6*np.pi,150)
yy = np.sin(xx)/xx
plt.figure(figsize=(15, 5))
plt.plot(xx,yy)
points = []
for i in range(-12, 13):
    if i % 2 == 0:
        points.append(r'%s$\pi$'%(i//2))
    else:
        points.append(r'$\dfrac{%s\pi}{2}$'%(i))
plt.xticks(np.arange(-6*np.pi,6*np.pi+np.pi/2,np.pi/2), points)
plt.title('y = $sin(x)/x$')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %% [markdown]
# ## Exercise 3
# 1. Создайте цветовой график $sin(x)sin(y)$ на интервале $[−π,π]×[−π,π]$.
# 2. Создайте цветовой график $e^{-x^2-y^2}$ на интервале $[−3,3]×[−3,3]$.

# %%
x = np.linspace(-np.pi,np.pi,500)
y = np.linspace(-np.pi,np.pi,500)
X,Y = np.meshgrid(x,y)

Z = np.sin(X) * np.sin(Y)

fig, ax = plt.subplots(figsize=(6,5))

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())

p = ax.pcolor(X, Y, Z, norm = norm, cmap= 'gnuplot2')
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])

# %%
x = np.linspace(-3, 3 ,500)
y = np.linspace(-3, 3,500)
X,Y = np.meshgrid(x,y)

Z = np.exp(-X*X-Y*Y)

fig, ax = plt.subplots(figsize=(6,5))

norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())

p = ax.pcolor(X, Y, Z, norm = norm, cmap= 'gnuplot2')
ax.axis('tight')
ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(4))
ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(4))

cb = fig.colorbar(p, ax=ax)
cb.set_ticks([-1, -.5, 0, .5, 1])
